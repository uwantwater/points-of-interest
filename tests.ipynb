# %%
from OSMPythonTools.overpass import Overpass

# %%
x_coord, y_coord = 27.69474, 85.31902

# %%
rect = [x_coord - 0.04, y_coord - 0.04, x_coord + 0.04, y_coord + 0.04]
bounds = [round(coord, 5) for coord in rect]
overpass = Overpass()
try:
    response = overpass.query(f"(nwr[amenity=place_of_worship][wikipedia~'.*']({bounds[0]}, {bounds[1]}, {bounds[2]}, {bounds[3]});nwr[tourism=attraction][wikipedia~'.*']({bounds[0]}, {bounds[1]}, {bounds[2]}, {bounds[3]});); out body;")
except:
    pass
response = response.toJSON()

# %%
response
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.1 084b4234',
#  'osm3s': {'timestamp_osm_base': '2024-06-05T09:54:30Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2207719953,
#    'lat': 27.6932983,
#    'lon': 85.2816525,
#    'tags': {'addr:city': 'kathmandu',
#     'addr:street': 'mathaticth marg',
#     'addr:tole': 'bafal tol',
#     'amenity': 'place_of_worship',
#     'name': 'कलंकी',
#     'name:en': 'Kalanki',
#     'name:ne': 'कलंकी',
#     'operator': 'private',
#     'place': 'suburb',
#     'religion': 'hindu',
#     'wikidata': 'Q3422922',
#     'wikipedia': 'en:Sitapaila'}},
#   {'type': 'node',
#    'id': 2230569085,
#    'lat': 27.6733988,
#    'lon': 85.3250562,
#    'tags': {'name': 'पाटन दरवार क्षेत्र',
#     'name:en': 'Patan Durbar Square',
#     'name:hi': 'पाटन दरबार चौक',
#     'tourism': 'attraction',
#     'wikidata': 'Q7144236',
#     'wikipedia': 'en:Patan Durbar Square'}},
#   {'type': 'way',
#    'id': 183558418,
#    'nodes': [1939604368,
#     4300163804,
#     4300163747,
#     1939604396,
#     1939604401,
#     1939604368],
#    'tags': {'amenity': 'place_of_worship',
#     'building': 'temple',
#     'name': 'Kasthamandap',
#     'religion': 'hindu',
#     'wikidata': 'Q6374805',
#     'wikipedia': 'ne:काष्ठमण्डप'}},
#   {'type': 'way',
#    'id': 196261745,
#    'nodes': [2066112673, 2066112676, 2066112677, 2066112674, 2066112673],
#    'tags': {'amenity': 'place_of_worship',
#     'building': 'temple',
#     'name': 'Kal Bhairab Temple',
#     'religion': 'hindu',
#     'wikidata': 'Q106208411',
#     'wikipedia': 'en:Kaal Bhairav, Kathmandu'}},
#   {'type': 'way',
#    'id': 201223707,
#    'nodes': [2111818744,
#     2111818743,
#     2111818741,
#     2111818739,
#     4210720839,
#     2111818740,
#     4210720378,
#     2111818742,
#     2111818747,
#     2111818748,
#     2111818751,
#     4210720771,
#     2111818752,
#     4210721891,
#     2111818755,
#     4210721893,
#     2111818756,
#     4210721894,
#     2111818754,
#     4210721892,
#     2111818753,
#     2111818750,
#     4210720770,
#     2111818749,
#     2111818746,
#     2111818744],
#    'tags': {'amenity': 'place_of_worship',
#     'building': 'yes',
#     'building:colour': '#fcecc0',
#     'building:levels': '1',
#     'height': '12',
#     'historic': 'yes',
#     'man_made': 'tower',
#     'name': 'Swayambhunath',
#     'name:ne': 'स्वयंभुनाथ',
#     'name:new': 'स्वयंभु',
#     'note': "tourists may call it monkey temple, but that's not a name.",
#     'religion': 'buddhist',
#     'roof:colour': 'white',
#     'roof:height': '11',
#     'roof:shape': 'dome',
#     'tower:type': 'stupa',
#     'wikipedia': 'en:Swayambhunath'}},
#   {'type': 'way',
#    'id': 420797418,
#    'nodes': [4207068060, 4207075071, 4207074558, 4207074145, 4207068060],
#    'tags': {'amenity': 'place_of_worship',
#     'building': 'yes',
#     'building:colour': 'brown',
#     'height': '2',
#     'name': 'Taleju Temple',
#     'roof:colour': 'brown',
#     'wikidata': 'Q83776242',
#     'wikipedia': 'en:Taleju Temple, Kathmandu'}},
#   {'type': 'way',
#    'id': 1257513676,
#    'nodes': [11691231121,
#     11691231122,
#     11691231123,
#     11691231124,
#     11691231125,
#     11691231126,
#     11691231127,
#     11691231128,
#     11691231129,
#     11691231130,
#     11691231131,
#     11691231132,
#     11691231133,
#     11691231134,
#     11691231135,
#     11691231136,
#     11691231137,
#     11691231138,
#     11691231139,
#     11691231140,
#     11691231141,
#     11691231142,
#     11691231143,
#     11691231144,
#     11691231145,
#     11691231146,
#     11691231147,
#     11691231148,
#     11691231149,
#     4861407039,
#     4861407040,
#     4861381353,
#     4861407052,
#     4861407053,
#     4861407054,
#     4861407055,
#     4861407056,
#     4861407057,
#     11691231150,
#     11691231151,
#     11691231152,
#     11691231153,
#     11691231154,
#     11691231155,
#     11691231156,
#     11691231157,
#     11691231158,
#     11691231159,
#     11691231160,
#     11691231161,
#     11691231162,
#     11691231163,
#     11691231164,
#     11691231165,
#     11691231166,
#     11691231167,
#     11691231168,
#     11691240369,
#     11691240370,
#     11691240371,
#     11691240372,
#     11691240373,
#     11691231121],
#    'tags': {'access': 'customers',
#     'area:highway': 'pedestrian',
#     'fee': 'yes',
#     'name': 'वसन्तपुर दरबार क्षेत्र',
#     'name:ar': 'ساحة دوربار كاتماندو',
#     'name:de': 'Kathmandu Durbar Square',
#     'name:en': 'Basantapur Durbar Square',
#     'name:hi': 'काठमांडू दरबार चौक',
#     'name:ko': '더르바르 광장',
#     'place': 'square',
#     'surface': 'sett',
#     'tourism': 'attraction',
#     'wheelchair': 'no',
#     'wikidata': 'Q6122177',
#     'wikipedia': 'en:Kathmandu Durbar Square'}},
#   {'type': 'relation',
#    'id': 4624856,
#    'members': [{'type': 'way', 'ref': 330027020, 'role': 'outer'},
#     {'type': 'way', 'ref': 330027023, 'role': 'inner'}],
#    'tags': {'alt_name:en': 'Golden Temple',
#     'amenity': 'place_of_worship',
#     'building': 'temple',
#     'name': 'हिरण्यवर्ण महाविहार',
#     'name:en': 'Hiranya Varna Mahavihar',
#     'religion': 'hindu',
#     'type': 'multipolygon',
#     'wikidata': 'Q5769439',
#     'wikipedia': 'en:Hiranya Varna Mahavihar'}}]}

# %%
response["elements"][0]["tags"]["name:en"]
# Out:
# 'Kalanki'
